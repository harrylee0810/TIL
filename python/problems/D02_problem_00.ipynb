# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
print(btc)
# Out:
# {'opening_price': '4266000', 'closing_price': '4331000', 'min_price': '4240000', 'max_price': '4379000', 'average_price': '4308724.2249', 'units_traded': '15801.2135765', 'volume_1day': '15801.2135765', 'volume_7day': '43048.60966475', 'buy_price': '4330000', 'sell_price': '4337000', '24H_fluctate': '65000', '24H_fluctate_rate': '1.52', 'date': '1546490336834'}

# %%
# 아래에 코드를 작성하세요.
init_p = int(btc['opening_price'])
max_p = int(btc['max_price'])
min_p = int(btc['min_price'])
deviation = max_p - min_p
if init_p + deviation > max_p:
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
print(currency)
# Out:
# {'BTC': {'opening_price': '4269000', 'closing_price': '4328000', 'min_price': '4240000', 'max_price': '4379000', 'average_price': '4309052.2244', 'units_traded': '15822.21705073', 'volume_1day': '15822.21705073', 'volume_7day': '43059.00396634', 'buy_price': '4328000', 'sell_price': '4330000', '24H_fluctate': '59000', '24H_fluctate_rate': '1.38'}, 'ETH': {'opening_price': '157700', 'closing_price': '171600', 'min_price': '156600', 'max_price': '174000', 'average_price': '167886.5733', 'units_traded': '523807.87114093', 'volume_1day': '523807.87114093', 'volume_7day': '1549711.385746324597840048', 'buy_price': '171600', 'sell_price': '171700', '24H_fluctate': '13900', '24H_fluctate_rate': '8.81'}, 'DASH': {'opening_price': '89600', 'closing_price': '93400', 'min_price': '88000', 'max_price': '94800', 'average_price': '93106.1144', 'units_traded': '4481024.29333055', 'volume_1day': '4481024.29333055', 'volume_7day': '35204929.56632653', 'buy_price': '93050', 'sell_price': '93300', '24H_fluctate': '3800', '24H_fluctate_rate': '4.24'}, 'LTC': {'opening_price': '35480', 'closing_price': '36800', 'min_price': '35230', 'max_price': '37330', 'average_price': '36413.4785', 'units_traded': '74867.90984569', 'volume_1day': '74867.90984569', 'volume_7day': '178318.34450726', 'buy_price': '36670', 'sell_price': '36740', '24H_fluctate': '1320', '24H_fluctate_rate': '3.72'}, 'ETC': {'opening_price': '5845', 'closing_price': '5965', 'min_price': '5785', 'max_price': '6040', 'average_price': '5947.8064', 'units_traded': '189023.95017705', 'volume_1day': '189023.95017705', 'volume_7day': '1929409.401296646632995491', 'buy_price': '5945', 'sell_price': '5965', '24H_fluctate': '120', '24H_fluctate_rate': '2.05'}, 'XRP': {'opening_price': '403', 'closing_price': '411', 'min_price': '399', 'max_price': '420', 'average_price': '410.289', 'units_traded': '73432847.10607202', 'volume_1day': '73432847.10607202', 'volume_7day': '507452330.34056138', 'buy_price': '411', 'sell_price': '412', '24H_fluctate': '8', '24H_fluctate_rate': '1.98'}, 'BCH': {'opening_price': '182300', 'closing_price': '188700', 'min_price': '179600', 'max_price': '195900', 'average_price': '186301.3405', 'units_traded': '77289.61236728', 'volume_1day': '77289.61236728', 'volume_7day': '607854.39205281', 'buy_price': '188600', 'sell_price': '188700', '24H_fluctate': '6400', '24H_fluctate_rate': '3.51'}, 'XMR': {'opening_price': '53600', 'closing_price': '57150', 'min_price': '53400', 'max_price': '59600', 'average_price': '57467.1373', 'units_traded': '12330954.64590932', 'volume_1day': '12330954.64590932', 'volume_7day': '55998869.42029975087', 'buy_price': '57100', 'sell_price': '57300', '24H_fluctate': '3550', '24H_fluctate_rate': '6.62'}, 'ZEC': {'opening_price': '65300', 'closing_price': '67150', 'min_price': '64400', 'max_price': '69150', 'average_price': '67004.6916', 'units_traded': '884892.02451206', 'volume_1day': '884892.02451206', 'volume_7day': '42233771.09704041', 'buy_price': '67050', 'sell_price': '67150', '24H_fluctate': '1850', '24H_fluctate_rate': '2.83'}, 'QTUM': {'opening_price': '2490', 'closing_price': '2558', 'min_price': '2434', 'max_price': '2599', 'average_price': '2528.8757', 'units_traded': '346220.68200913', 'volume_1day': '346220.68200913', 'volume_7day': '5291162.26463097', 'buy_price': '2555', 'sell_price': '2560', '24H_fluctate': '68', '24H_fluctate_rate': '2.73'}, 'BTG': {'opening_price': '14560', 'closing_price': '14960', 'min_price': '14300', 'max_price': '15100', 'average_price': '14884.5399', 'units_traded': '20749888.87130743', 'volume_1day': '20749888.87130743', 'volume_7day': '95384807.51321575', 'buy_price': '14850', 'sell_price': '14950', '24H_fluctate': '400', '24H_fluctate_rate': '2.74'}, 'EOS': {'opening_price': '2943', 'closing_price': '3140', 'min_price': '2926', 'max_price': '3204', 'average_price': '3080.7311', 'units_traded': '3668240.51208754', 'volume_1day': '3668240.51208754', 'volume_7day': '24552183.00526815', 'buy_price': '3 ...

# %%
# 아래에 코드를 작성하세요.

for k,v in currency.items():
    #1번째 돌리기: key == 'BTC', value == {'opening_price':'4269000','closing_price':'4328000', .....}
    try:
        a = float(v['opening_price']) + float(v['max_price']) - float(v['min_price'])
        b = float(v['max_price'])
        if a > b:
            print(f'{k} 상승장')
        else:
            print(f'{k} 하락장')
    
    except TypeError:
        pass

    
#     if int(i['opening_prices'])+int(i['max_prices'])-int(i['min_prices']) > int(i['max_prices']):
#         print(f'{i} 상승장')
#     else:
#         print('하락장')
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 하락장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 하락장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 하락장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ROM 상승장
# AMO 상승장

# %%
#if 'max_price' in v:

for k,v in currency.items():
    #1번째 돌리기: key == 'BTC', value == {'opening_price':'4269000','closing_price':'4328000', .....}
    if 'max_price' in v:
        a = float(v['opening_price']) + float(v['max_price']) - float(v['min_price'])
        b = float(v['max_price'])
        if a > b:
            print(f'{k} 상승장')
        else:
            print(f'{k} 하락장')
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 하락장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 하락장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 하락장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ROM 상승장
# AMO 상승장

# %%
#if type(v) == type({}):

for k,v in currency.items():
    #1번째 돌리기: key == 'BTC', value == {'opening_price':'4269000','closing_price':'4328000', .....}
    if type(v) == type({}):
        a = float(v['opening_price']) + float(v['max_price']) - float(v['min_price'])
        b = float(v['max_price'])
        if a > b:
            print(f'{k} 상승장')
        else:
            print(f'{k} 하락장')
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 하락장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 하락장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 하락장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ROM 상승장
# AMO 상승장

# %%
#if isinstance(v,dict):

for k,v in currency.items():
    #1번째 돌리기: key == 'BTC', value == {'opening_price':'4269000','closing_price':'4328000', .....}
    if isinstance(v,dict):
        a = float(v['opening_price']) + float(v['max_price']) - float(v['min_price'])
        b = float(v['max_price'])
        if a > b:
            print(f'{k} 상승장')
        else:
            print(f'{k} 하락장')
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 하락장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 하락장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 하락장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ROM 상승장
# AMO 상승장
